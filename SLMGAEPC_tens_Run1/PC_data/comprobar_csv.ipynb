# %%
import pandas as pd
import numpy as np

lista_arc = [
    'F1_F2_coexpr_for_train.csv',
    'F1_F2_me_for_train.csv',
    'F1_F2_pathway_for_train.csv',
    'F1_F2_ppi_for_train.csv',
    'F1_F2_proteincomplex_for_train.csv'
]

# %%
for arch in lista_arc:
    leido = pd.read_csv(arch)
    print(leido.shape)
# Out:
# (17755, 17755)
# (17755, 17755)
# (17755, 17755)
# (17755, 17755)
# (17755, 17755)
